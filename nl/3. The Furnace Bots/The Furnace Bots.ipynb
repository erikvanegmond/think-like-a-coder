# %%
from bots import bots, generate_bots
from IPython.display import YouTubeVideo

# %% [raw]
# bot = bots.check_bot(1)
# print(bot)
# print(bot.fornuis_number)

# %% [markdown]
# # De fornuis bots

# %%
YouTubeVideo(id="wQPArC8NN5o",width="560", height="315")

# %% [markdown]
# ## Wat Hedge kan doen
# **Alle shell serie nummers in één oogopslag zien**:
# ```python
# bots
# ```
# ```text
# [1,5,2,3,6,4,...]
# ```
#
# **check fornuis nummers één voor één**:
# ```python
# bot = bots.check_bot(1)
# print(bot)
# print(bot.fornuis_nummer)
# ```
#
# ```tekst
# Bot(fornuis_nummer=3932, serie_nummer=1)
# 3932
# ```
#
# **Note**: Het duurt even om een bot te checken! Het duurt hier één seconde per bot.
#
# ## Gebruik loops
# Zie episode 1
# * For loops
# * While loops
#
# Zo kan je over de bots heen loopen:
# ```python
# for bot in bots:
#     print(bot)
# ```
#
#
# ## Gebruik conditionals
# Zie episode 2

# %% [markdown]
# # Programmeer Hedge hieronder
#
# Hieronder zie je de Fornuis Bots die Hedge tegenkomt. Je kan de tools die hierboven zijn geschreven gebruiken om Hedge te programmeren.
# Om Hedge de originele bot te laten vinde kan je de run knop gebruiken in het menu, of Ctrl+Enter

# %%
bots
# Out:
# [4800, 1476, 3334, 2517, 2337, 4628, 2143, 3802, 2354, 566, 4002, 3644, 2171, 3510, 3736, 618, 1725, 2282, 316, 1687, 3751, 3281, 4505, 1444, 3762, 1500, 2293, 1066, 4706, 3801, 3343, 2950, 3430, 2605, 4000, 3961, 2912, 2307, 921, 2403, 4227, 3293, 371, 4279, 4310, 3255, 2390, 1097, 192, 1627, 4766, 2813, 2038, 3280, 2964, 3206, 3631, 2377, 708, 2222, 4757, 2660, 489, 757, 3077, 4731, 3747, 2748, 4995, 2100, 2326, 1696, 3228, 733, 4156, 2001, 3121, 992, 4439, 3346, 185, 1177, 3302, 1268, 787, 1954, 4196, 4140, 2507, 1731, 227, 1123, 1230, 4130, 3775, 2583, 1179, 1930, 3855, 2459, 2576, 1345, 3489, 704, 177, 4145, 1973, 2373, 4627, 2141, 284, 2929, 2028, 1641, 1869, 1081, 193, 3310, 595, 3635, 4554, 4838, 578, 2682, 958, 970, 318, 1225, 348, 1803, 3441, 2864, 1788, 4522, 3980, 4885, 2411, 2931, 3894, 4968, 4889, 257, 1139, 1152, 1940, 2062, 1197, 2760, 412, 3411, 2022, 2182, 4458, 4474, 1250, 4585, 1900, 3992, 3788, 2900, 3391, 4436, 3022, 308, 2673, 3286, 4613, 1575, 2868, 161, 2415,
# ...
