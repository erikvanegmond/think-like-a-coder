# %%
from painting import Painting
from IPython.display import YouTubeVideo

# %% [markdown]
# # The Artists

# %%
YouTubeVideo(id="7mOev8v3D1U",width="560", height="315")

# %% [markdown]
# ## What Hedge can do
# **Move forward**
#
# ```python
# painting.move_forward()
# ```
#
# **Turn left or right**
# ```python
# painting.move_left()
# painting.move_right()
# ```
#
# **Measure the dimensions of the painting**
# ```python
# painting.size
# ```
# Output:
# ```text
# 13
# ```
#
# **Paint the pixel he is hovering over**
# ```python
# painting.paint()
# ```
#
#
# ## Use loops
# See episode 1
#
# ## Use conditionals
# See episode 2
#
# ## Use variables
# See episode 3

# %%
painting = Painting() # reset the painting

# Program the drawing here

painting.view()
