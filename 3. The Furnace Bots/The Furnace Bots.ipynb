# %%
from bots import bots, generate_bots
from IPython.display import YouTubeVideo

# %%
bot = bots.check_bot(1)
print(bot)
print(bot.furnace_number)
# Out:
# Bot(furnace_number=3932, serial_number=1)
# 3932

# %% [markdown]
# # The Furnace Bots

# %%
YouTubeVideo(id="wQPArC8NN5o",width="560", height="315")

# %% [markdown]
# ## What Hedge can do
# **See all shell serials numbers a glance**:
# ```python
# bots
# ```
# ```text
# [1,5,2,3,6,4,...]
# ```
#
# **Check furnace numbers one at a time**:
# ```python
# bot = bots.check_bot(1)
# print(bot)
# print(bot.furnace_number)
# ```
#
# ```text
# Bot(furnace_number=3932, serial_number=1)
# 3932
# ```
#
# **Note**: Checking a bot takes some time! Here it takes one second to check one bot.
#
# ## Use loops
# See episode 1
# * For loops
# * While loops
#
# You can loop over bots like this:
# ```python
# for bot in bots:
#     print(bot)
# ```
#
#
# ## Use conditionals
# See episode 2

# %% [markdown]
# # Program Hedge below
#
# Below you see the Furnace Bots that Hedge encounters. You can use the tools described above to program Hedge.
# To let Hedge try to find the original bot you can press the run button in the menu, or press Ctrl+Enter

# %%
bots
# Out:
# [4876, 377, 3049, 1539, 2924, 175, 4668, 4718, 3100, 4095, 3662, 4390, 1358, 569, 1154, 1741, 1180, 1365, 140, 1961, 4925, 4954, 2913, 3424, 2596, 3824, 4050, 2731, 32, 1041, 3854, 4717, 2476, 138, 1688, 247, 3067, 3942, 1614, 3997, 760, 1846, 1621, 4423, 4433, 4318, 4185, 3959, 2863, 2919, 2585, 1467, 4467, 4910, 4712, 1050, 2307, 3038, 3716, 2081, 1868, 3790, 2530, 2171, 168, 3941, 2264, 3267, 4330, 1883, 2194, 779, 3293, 3524, 1163, 1469, 3551, 4404, 3456, 1303, 40, 4383, 3227, 3025, 3066, 4608, 446, 3318, 92, 4605, 1528, 4732, 109, 658, 1534, 3483, 352, 3033, 1902, 1853, 7, 646, 1822, 1970, 2621, 4320, 4882, 38, 727, 4353, 1332, 2824, 3044, 2872, 4849, 610, 1758, 2345, 2961, 3879, 2216, 2819, 285, 3880, 4979, 1275, 4505, 1753, 2395, 2052, 1824, 1510, 2467, 2841, 2183, 2023, 3404, 4581, 1063, 4432, 4966, 2836, 3967, 661, 1189, 4165, 4175, 2266, 2203, 2343, 1826, 243, 4517, 287, 3289, 1475, 1950, 1075, 3124, 4121, 3397, 3275, 1362, 223, 1028, 4552, 1417, 131, 4475, 4394, 4817, 4923
# ...
