# %%
from IPython.display import YouTubeVideo
from structure import Structure

# %% [markdown]
# # The Tower of Epiphany

# %%
YouTubeVideo(id="Xq-szohkAqU",width="560", height="315")

# %% [markdown]
# ## What Hedge can do
# **Choose which column of blocks is visible**
# *at most one at a time*
#
# ```python
# level1.view_column(1)
# ```
# Output is the height of the column:
# ```text
# 6
# ```
#
# You can also draw the column. Your program can't do anything with that, but it will help you visualise the structure.
# ```python
# level1.draw_column(1)
# ```
#
# **Check the width of the structure**
# ```python
# level1.width
# ```
# Output is the width of the structure:
# ```text
# 15
# ```
#
# **Supply energy**
# ```python
# level1.supply_energy(10)
# ```
#
# ## Use loops
# See episode 1
#
# You can loop using range()
# ```python
# for i in range(5):
#     print(i)
# ```
# Output:
# ```text
# 0
# 1
# 2
# 3
# 4
# ```
#
#
# ## Use conditionals
# See episode 2
#
# ## Use variables
# See episode 3
#
# **Create a list**
# ```python
# my_list = [1,2,3]
# ```
#
# **Create an empty list**
# ```python
# my_list = []
# ```
#
# **Add an item to a list**
# ```python
# my_list = [1,2,3]
# my_list.append(4)
# print(my_list)
# ```
# Output:
# ```text
# [1,2,3,4]
# ```

# %%
level1 = Structure(3)
level2 = Structure(9)
level3 = Structure(36)

# %% [markdown]
# # Program Hedge below
# There are three levels, created in the cell above. You can regenerate the levels by running that cell.

# %%
level1.view_column(0)

# %%
level1.view_column(0)
# Out:
# 13
