# %%
from IPython.display import YouTubeVideo
from crowd import crowd

# %% [markdown]
# # The Resistance

# %%
YouTubeVideo(id="axBuiB55CfA",width="560", height="315")

# %% [markdown]
# ## What Hedge can do
# **Check people's facial characteristics**:
# ```python
# person.check_hair()
# person.check_eyes()
# person.check_glasses()
# ```
# **Get the name**:
# ```python
# person.ask_name()
# ```
#
# **Check if at least one consecutive letter in the name**
# ```python
# person.at_least_one_consecutive()
# ```
#
# **Count the number of vowels in the name**
# ```python
# person.number_of_vowels()
# ```
#
# ## Use loops
# See episode 1
# * For loops
# * While loops
#
# You can stop a loop with `break`
#
# ```python
# for i in range(100):
#     print(i)
#     break
# ```
# ```text
# 0
# ```
#
#
# ## Use conditionals
# ```python
# if person.check_glasses():
#     print("The person has glasses!")
# else:
#     print("The person has no glasses!")
#
#
# if person.check_hair() == "brown":
#     print("The person has brown hair!")
# else:
#     print("The person does not have brown hair!")
#
# ```
# The else clause is not necessary.
#
#
# #### How to check values
# | Operator | Description           |
# |----------|-----------------------|
# | ==       | Equals                |
# | !=       | Not equals            |
# | <        | Less than             |
# | >        | Greater then          |
# | <=       | Less then or equal    |
# | >=       | Greater then or equal |

# %% [markdown]
# # Program Hedge below
#
# Below you see the crowd that Hedge encounters. You can use the tools described above to program Hedge.
# To let Hedge try to find the leader of the resistance you can press the run button in the menu, or press Ctrl+Enter

# %%
crowd
# Out:
# [Person(eye_color=green, hair_color=black, glasses=False, name=Kevin),
#  Person(eye_color=blue, hair_color=brown, glasses=True, name=Brian),
#  Person(eye_color=brown, hair_color=black, glasses=False, name=Sylvia),
#  Person(eye_color=blue, hair_color=blond, glasses=False, name=Ronald),
#  Person(eye_color=brown, hair_color=brown, glasses=True, name=Nathaniel),
#  Person(eye_color=brown, hair_color=blue, glasses=False, name=Kayla),
#  Person(eye_color=brown, hair_color=brown, glasses=False, name=Julianne),
#  Person(eye_color=brown, hair_color=brown, glasses=True, name=Ruby),
#  Person(eye_color=brown, hair_color=black, glasses=False, name=Thomas),
#  Person(eye_color=brown, hair_color=green, glasses=False, name=Kendra),
#  Person(eye_color=brown, hair_color=brown, glasses=False, name=Mildred),
#  Person(eye_color=brown, hair_color=red, glasses=False, name=Margaret),
#  Person(eye_color=brown, hair_color=brown, glasses=False, name=Marvin),
# ...
